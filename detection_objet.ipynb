# %%
import matplotlib.pyplot as plt
img = plt.imread('image.jpeg')
plt.imshow(img)

# %%
img.shape
# Out:
# (520, 1365, 3)

# %%
import matplotlib.patches as patches
rect = patches.Rectangle((550,280),250,240, linewidth=5, facecolor='none',
                        edgecolor='red') #pas de 280

# %%
rect

# %%
fig,ax = plt.subplots(1,figsize=(12,12))
ax.add_patch(rect)
plt.imshow(img)

# %%
plt.imshow(img[300:550,530:780])  #pas de 300
